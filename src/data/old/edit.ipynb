# %%
import pandas as pd

# 1. Read the json file you saved from the model
df = pd.read_json("qa_pairs.json")  # path to your .json file

# 2. Write to CSV with two columns: question, answer
df.to_csv("qa_pairs.csv", index=False)

# %%
import pandas as pd

# Read the CSV into a DataFrame
df = pd.read_csv("qa_pairs.csv")  # path to your CSV

print(df.head())        # show first rows
print(df.columns)       # should
# Out:
#                                             question  answer
# 0  In 2024, how many million daily trips were mad...    26.6
# 1  By what percentage did daily trips in London i...     1.7
# 2  In 2024, how many million daily journey stages...    30.2
# 3  What was the percentage increase in daily jour...     1.6
# 4  In 2024, what percentage of all trips in Londo...    63.4
# Index(['question', 'answer'], dtype='object')

# %%
df
# Out:
#                                               question  answer
# 0    In 2024, how many million daily trips were mad...    26.6
# 1    By what percentage did daily trips in London i...     1.7
# 2    In 2024, how many million daily journey stages...    30.2
# 3    What was the percentage increase in daily jour...     1.6
# 4    In 2024, what percentage of all trips in Londo...    63.4
# ..                                                 ...     ...
# 111  Across London as a whole, by what percentage d...     0.8
# 112  In 2024–25, what percentage of London resident...    43.3
# 113  What was the corresponding percentage of Londo...    39.6
# 114  What was the percentage of London residents ac...    42.4
# 115  What is the monitoring target percentage for L...    70.0
#
# [116 rows x 2 columns]
